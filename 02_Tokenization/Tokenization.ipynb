# %% [markdown]
# <a href="https://colab.research.google.com/github/pulkit48/NLP/blob/main/02_Tokenization/Tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy

# %%
nlp=spacy.load('en_core_web_sm')
doc=nlp("Dr.strange loves pavbhaji of mumbai.Hulk loves chaat of delhi")
for sentence in doc.sents:
  print(sentence)
# Out:
# Dr.strange loves pavbhaji of mumbai.
# Hulk loves chaat of delhi

# %%
for sentence in doc.sents:
  for word in sentence:
    print(word)
# Out:
# Dr.strange
# loves
# pavbhaji
# of
# mumbai
# .
# Hulk
# loves
# chaat
# of
# delhi

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.tokenize import sent_tokenize
sent_tokenize("Dr. Strange loves pavbhaji of mumbai. Hulk loves chaat of delhi")
# Out:
# ['Dr.', 'Strange loves pavbhaji of mumbai.', 'Hulk loves chaat of delhi']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from nltk import word_tokenize
word_tokenize("Dr.strange loves pavbhaji of mumbai.Hulk loves chaat of delhi")
# Out:
# ['Dr.strange',
#  'loves',
#  'pavbhaji',
#  'of',
#  'mumbai.Hulk',
#  'loves',
#  'chaat',
#  'of',
#  'delhi']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Module 2

# %%
import spacy

# %%
nlp=spacy.blank("en")
doc=nlp("Dr. Strange loves Pav Bhaji of mumbai as it costs only 25 per plate.")
for token in doc:
  print(token)
# Out:
# Dr.
# Strange
# loves
# Pav
# Bhaji
# of
# mumbai
# as
# it
# costs
# only
# 25
# per
# plate
# .

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
doc[1]
# Out:
# Strange

# %%
# nlp=spacy.blank("en")
# doc=nlp("Let's go to N.Y.!")
# for token in doc:
#   print(token)
# Out:
# Let
# 's
# go
# to
# N.Y.
# !

# %%
type(nlp)
# Out:
# spacy.lang.en.English

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %%
token0=doc[0]

# %%
type(token0)
# Out:
# spacy.tokens.token.Token

# %%
dir(token0)
# Out:
# ['_',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  'ancestors',
#  'check_flag',
#  'children',
#  'cluster',
#  'conjuncts',
#  'dep',
#  'dep_',
#  'doc',
#  'ent_id',
#  'ent_id_',
#  'ent_iob',
#  'ent_iob_',
#  'ent_kb_id',
#  'ent_kb_id_',
#  'ent_type',
#  'ent_type_',
#  'get_extension',
#  'has_dep',
#  'has_extension',
#  'has_head',
#  'has_morph',
#  'has_vector',
#  'head',
#  'i',
#  'idx',
#  'iob_strings',
#  'is_alpha',
#  'is_ancestor',
#  'is_ascii',
#  'is_bracket',
#  'is_currency',
#  'is_digit',
#  'is_left_punct',
#  'is_lower',
#  'is_oov',
#  'is_punct',
# ...

# %%
token0.like_num
# Out:
# False

# %%
token2=doc[11]

# %%
token2.like_num
# Out:
# True

# %%
doc=nlp("Dr. Strange loves Pav Bhaji of mumbai as it costs only 25 per plate.")
tokens=[token.text for token in doc]
tokens
# Out:
# ['Dr.',
#  'Strange',
#  'loves',
#  'Pav',
#  'Bhaji',
#  'of',
#  'mumbai',
#  'as',
#  'it',
#  'costs',
#  'only',
#  '25',
#  'per',
#  'plate',
#  '.']

# %%
doc=nlp("Dr. Strange loves Pav Bhaji of mumbai as it costs only 25 per plate.")
for sentences in doc.sents:
  print(sentences)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-7de4221f8f8f> in <cell line: 2>()
#       1 doc=nlp("Dr. Strange loves Pav Bhaji of mumbai as it costs only 25 per plate.")
# ----> 2 for sentences in doc.sents:
#       3   print(sentences)
#
# /usr/local/lib/python3.10/dist-packages/spacy/tokens/doc.pyx in sents()
#
# ValueError: [E030] Sentence boundaries unset. You can add the 'sentencizer' component to the pipeline with: `nlp.add_pipe('sentencizer')`. Alternatively, add the dependency parser or sentence recognizer, or set sentence boundaries by setting `doc[i].is_sent_start`.

# %%
nlp.pipe_names
# Out:
# []

# %%
nlp.add_pipe('sentencizer')

# %%
doc=nlp("Dr. Strange loves Pav Bhaji of mumbai as it costs only 25 per plate.")
for sentences in doc.sents:
  print(sentences)
# Out:
# Dr. Strange loves Pav Bhaji of mumbai as it costs only 25 per plate.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from spacy.symbols import ORTH

nlp = spacy.blank("en")
doc = nlp("gimme double cheese extra large healthy pizza")
tokens = [token.text for token in doc]
tokens
# Out:
# ['gimme', 'double', 'cheese', 'extra', 'large', 'healthy', 'pizza']

# %%
nlp.tokenizer.add_special_case("gimme", [
    {ORTH: "gim"},
    {ORTH: "me"},
])
doc = nlp("gimme double cheese extra large healthy pizza")
tokens = [token.text for token in doc]
tokens
# Out:
# ['gim', 'me', 'double', 'cheese', 'extra', 'large', 'healthy', 'pizza']
